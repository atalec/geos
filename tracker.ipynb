# %% [markdown]
# Get headlines into memory

# %%
f = open('headlines.txt', 'r')
headlines = [line.strip() for line in f.readlines()]
headlines[:10]
# Out:
# ['Zika Outbreak Hits Miami',
#  'Could Zika Reach New York City?',
#  'First Case of Zika in Miami Beach',
#  'Mystery Virus Spreads in Recife, Brazil',
#  'Dallas man comes down with case of Zika',
#  'Trinidad confirms first Zika case',
#  'Zika Concerns are Spreading in Houston',
#  'Geneve Scientists Battle to Find Cure',
#  'The CDC in Atlanta is Growing Worried',
#  'Zika Infested Monkeys in Sao Paulo']

# %% [markdown]
# Get all country names

# %%
from geonamescache import GeonamesCache
gc = GeonamesCache()

countries = [country['name']for country in gc.get_countries().values()]
countries[125:150]
# Out:
# ['Kazakhstan',
#  'Laos',
#  'Lebanon',
#  'Saint Lucia',
#  'Liechtenstein',
#  'Sri Lanka',
#  'Liberia',
#  'Lesotho',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'Libya',
#  'Morocco',
#  'Monaco',
#  'Moldova',
#  'Montenegro',
#  'Saint Martin',
#  'Madagascar',
#  'Marshall Islands',
#  'Macedonia',
#  'Mali',
#  'Myanmar',
#  'Mongolia',
#  'Macao',
#  'Northern Mariana Islands']

# %% [markdown]
# Create the regular expression dictionary for the country names.
# - Requires the unidecode name to be included in the dictionary key
# - SAMPLE: {(unidecode_name|name) : name}

# %%
from unidecode import unidecode
import re
def create_regex_from_name(name):
    unidecode_name = unidecode(name)
    if name != unidecode:
        r = fr'\b({name}|{unidecode_name})\b'
    else:
        r = fr'\b{name}\b'
    return re.compile(r, flags=re.IGNORECASE)

# %%
countries_re = {create_regex_from_name(c): c  for c in countries}

# %% [markdown]
# Get city names

# %%
cities = [city['name'] for city in gc.get_cities().values()]
cities[:5]
# Out:
# ['Andorra la Vella',
#  'Umm Al Quwain City',
#  'Ras Al Khaimah City',
#  'Zayed City',
#  'Khawr Fakkān']

# %% [markdown]
# Build the regex function for getting the city name from the headlines

# %%
cities_re = {create_regex_from_name(c): c for c in cities}

# %%
def reg_extract(regex_pattern, city_name):
    match = re.match(regex_pattern, city_name)
    if match is not None:
        start, end = match.start(), match.end()
        return city_name[start:end]
    else:
        return ''

# %%
import pandas as pd
df = pd.DataFrame(headlines)
df = df.rename(columns={0:'headlines'})
df
# Out:
#                                              headlines
# 0                             Zika Outbreak Hits Miami
# 1                      Could Zika Reach New York City?
# 2                    First Case of Zika in Miami Beach
# 3              Mystery Virus Spreads in Recife, Brazil
# 4              Dallas man comes down with case of Zika
# ..                                                 ...
# 645  Rumors about Rabies spreading in Jerusalem hav...
# 646              More Zika patients reported in Indang
# 647  Suva authorities confirmed the spread of Rotav...
# 648         More Zika patients reported in Bella Vista
# 649                     Zika Outbreak in Wichita Falls
#
# [650 rows x 1 columns]

# %%
h ='Mad Cow Disease Hits London'
for regex, name in cities_re.items():
    if regex.search(h):
        print(name)
# Out:
# London

# %%
def city_in_headline(headline, re_dictionary):
    for regex, name in re_dictionary.items():
        if regex.search(headline):
            return name
    return None

# %%
df['City'] = df['headlines'].apply(lambda x : city_in_headline(x, cities_re))
df
# Out:
#                                              headlines         City
# 0                             Zika Outbreak Hits Miami        Miami
# 1                      Could Zika Reach New York City?         York
# 2                    First Case of Zika in Miami Beach           Of
# 3              Mystery Virus Spreads in Recife, Brazil       Recife
# 4              Dallas man comes down with case of Zika          Man
# ..                                                 ...          ...
# 645  Rumors about Rabies spreading in Jerusalem hav...    Jerusalem
# 646              More Zika patients reported in Indang       Indang
# 647  Suva authorities confirmed the spread of Rotav...         Suva
# 648         More Zika patients reported in Bella Vista  Bella Vista
# 649                     Zika Outbreak in Wichita Falls      Wichita
#
# [650 rows x 2 columns]

# %%
df.describe()
# Out:
#                                    headlines City
# count                                    650  618
# unique                                   647  504
# top     Spanish Flu Spreading through Madrid   Of
# freq                                       2   61

# %%
df[df['City'].str.len() <= 4]
# Out:
#                                              headlines  City        Country  \
# 45                 Lima tries to address Zika Concerns  Lima           Peru
# 71                      Pune woman diagnosed with Zika  Pune          India
# 80   Authorities are Worried about the Spread of Ma...  Rome          Italy
# 130                Molo Cholera Spread Causing Concern  Molo          Kenya
# 171                               Zika arrives in Miri  Miri       Malaysia
# 273  More people in Nadi are infected with HIV ever...  Nadi           Fiji
# 283  Rumors about Tuberculosis Spreading in Baud ha...  Baud          India
# 320                     Chikungunya re-emerges in Kobe  Kobe          Japan
# 363                More Zika patients reported in Waco  Waco  United States
# 365                        Erie County sets Zika traps  Erie  United States
# 396                       Kent is infested with Rabies  Kent  United States
# 409  The Spread of Gonorrhea in Reno has been Confi...  Reno  United States
# 437                      Zika symptoms spotted in Sibu  Sibu       Malaysia
# 452    The Spread of Herpes in Baku has been Confirmed  Baku     Azerbaijan
# 462  Contaminated Meat Brings Trouble for Bonn Farmers  Bonn        Germany
# 532                         Zika Troubles come to Jaen  Jaen    Philippines
# 579                       Zika seminars in Yuma County  Yuma  United States
# 617                   Mad Cow Disease Detected in Lyon  Lyon         France
# 635  Authorities are Worried about the Spread of He...  Yiwu          China
# 647  Suva authorities confirmed the spread of Rotav...  Suva           Fiji
#
#     Country_Code
# 45            PE
# 71            IN
# 80            IT
# 130           KE
# 171           MY
# 273           FJ
# 283           IN
# 320           JP
# 363           US
# 365           US
# 396           US
# 409           US
# 437           MY
# 452           AZ
# 462           DE
# 532           PH
# 579           US
# 617           FR
# 635           CN
# 647           FJ

# %% [markdown]
# Problem with data frame.  Ho and San were 'matched' instead of Ho Chi Minh and San Salvador

# %%
df[df['City'] == 'San']
# Out:
#                                              headlines City
# 361  How to Avoid Respiratory Syncytial Virus in Sa...  San
# 443            Bronchitis Keeps Spreading in San Mateo  San

# %%
def get_cities_in_headline(headline):
    cities_in_headline = set()
    for regex, name in cities_re.items():
        match = regex.search(headline)
        if match:
            if headline[match.start()].isupper():
                cities_in_headline.add(name)
    return list(cities_in_headline)

df['Cities'] = df['headlines'].apply(lambda x: get_cities_in_headline(x))
df
# Out:
#                                              headlines         City  \
# 0                             Zika Outbreak Hits Miami        Miami
# 1                      Could Zika Reach New York City?         York
# 2                    First Case of Zika in Miami Beach           Of
# 3              Mystery Virus Spreads in Recife, Brazil       Recife
# 4              Dallas man comes down with case of Zika          Man
# ..                                                 ...          ...
# 645  Rumors about Rabies spreading in Jerusalem hav...    Jerusalem
# 646              More Zika patients reported in Indang       Indang
# 647  Suva authorities confirmed the spread of Rotav...         Suva
# 648         More Zika patients reported in Bella Vista  Bella Vista
# 649                     Zika Outbreak in Wichita Falls      Wichita
#
#                        Cities
# 0                     [Miami]
# 1       [New York City, York]
# 2        [Miami Beach, Miami]
# 3                    [Recife]
# 4                    [Dallas]
# ..                        ...
# 645               [Jerusalem]
# 646                  [Indang]
# 647                    [Suva]
# 648      [Vista, Bella Vista]
# 649  [Wichita, Wichita Falls]
#
# [650 rows x 3 columns]

# %%
def get_longest_string_in_list(input_list):
    if input_list is not None:
        result = ''
        for l in input_list:
            if len(l) > len(result):
                result = l
        return result
    else:
        return None
df['City'] = df['Cities'].apply(lambda x: get_longest_string_in_list(x))
df
# Out:
#                                              headlines           City  \
# 0                             Zika Outbreak Hits Miami          Miami
# 1                      Could Zika Reach New York City?  New York City
# 2                    First Case of Zika in Miami Beach    Miami Beach
# 3              Mystery Virus Spreads in Recife, Brazil         Recife
# 4              Dallas man comes down with case of Zika         Dallas
# ..                                                 ...            ...
# 645  Rumors about Rabies spreading in Jerusalem hav...      Jerusalem
# 646              More Zika patients reported in Indang         Indang
# 647  Suva authorities confirmed the spread of Rotav...           Suva
# 648         More Zika patients reported in Bella Vista    Bella Vista
# 649                     Zika Outbreak in Wichita Falls  Wichita Falls
#
#                        Cities
# 0                     [Miami]
# 1       [New York City, York]
# 2        [Miami Beach, Miami]
# 3                    [Recife]
# 4                    [Dallas]
# ..                        ...
# 645               [Jerusalem]
# 646                  [Indang]
# 647                    [Suva]
# 648      [Vista, Bella Vista]
# 649  [Wichita, Wichita Falls]
#
# [650 rows x 3 columns]

# %%
def get_country_from_city_name(city_name):
    """This function assumes that the city with the largest population is the correct one"""
    if city_name:
   
        best_match = max(gc.get_cities_by_name(city_name),
                        key=lambda x: list(x.values())[0]['population'])
        if len(best_match.values()) > 0:
            best_match_data = list(best_match.values())[0]
            return best_match_data['countrycode']
    return None

print(get_country_from_city_name('San Francisco'))
print(get_country_from_city_name('Los Ángeles'))
print(get_country_from_city_name('Miami'))
print(get_country_from_city_name(None))
# Out:
# US
# CL
# US
# None

# %%
# get country name from code
def get_country_name_from_code(country_code):
    if country_code:
        for country in gc.get_countries().values():
            if country['iso'] == country_code.upper():
                return country['name']
        return None
    else:
        return None
print(get_country_name_from_code('AE'))
print(get_country_name_from_code('GB'))
print(get_country_name_from_code('US'))
print(get_country_name_from_code('DE'))
# Out:
# United Arab Emirates
# United Kingdom
# United States
# Germany

# %%
df['Country_Code'] = df['City'].apply(get_country_from_city_name)
df
# Out:
#                                              headlines           City  \
# 0                             Zika Outbreak Hits Miami          Miami
# 1                      Could Zika Reach New York City?  New York City
# 2                    First Case of Zika in Miami Beach    Miami Beach
# 3              Mystery Virus Spreads in Recife, Brazil         Recife
# 4              Dallas man comes down with case of Zika         Dallas
# ..                                                 ...            ...
# 645  Rumors about Rabies spreading in Jerusalem hav...      Jerusalem
# 646              More Zika patients reported in Indang         Indang
# 647  Suva authorities confirmed the spread of Rotav...           Suva
# 648         More Zika patients reported in Bella Vista    Bella Vista
# 649                     Zika Outbreak in Wichita Falls  Wichita Falls
#
#                        Cities             Country Country_Code
# 0                     [Miami]       United States           US
# 1       [New York City, York]       United States           US
# 2        [Miami Beach, Miami]       United States           US
# 3                    [Recife]              Brazil           BR
# 4                    [Dallas]       United States           US
# ..                        ...                 ...          ...
# 645               [Jerusalem]              Israel           IL
# 646                  [Indang]         Philippines           PH
# 647                    [Suva]                Fiji           FJ
# 648      [Vista, Bella Vista]  Dominican Republic           DO
# 649  [Wichita, Wichita Falls]       United States           US
#
# [650 rows x 5 columns]

# %%
df['Country'] = df['Country'].apply(get_country_name_from_code)
df
# Out:
#                                              headlines           City  \
# 0                             Zika Outbreak Hits Miami          Miami
# 1                      Could Zika Reach New York City?  New York City
# 2                    First Case of Zika in Miami Beach    Miami Beach
# 3              Mystery Virus Spreads in Recife, Brazil         Recife
# 4              Dallas man comes down with case of Zika         Dallas
# ..                                                 ...            ...
# 645  Rumors about Rabies spreading in Jerusalem hav...      Jerusalem
# 646              More Zika patients reported in Indang         Indang
# 647  Suva authorities confirmed the spread of Rotav...           Suva
# 648         More Zika patients reported in Bella Vista    Bella Vista
# 649                     Zika Outbreak in Wichita Falls  Wichita Falls
#
#                        Cities             Country
# 0                     [Miami]       United States
# 1       [New York City, York]       United States
# 2        [Miami Beach, Miami]       United States
# 3                    [Recife]              Brazil
# 4                    [Dallas]       United States
# ..                        ...                 ...
# 645               [Jerusalem]              Israel
# 646                  [Indang]         Philippines
# 647                    [Suva]                Fiji
# 648      [Vista, Bella Vista]  Dominican Republic
# 649  [Wichita, Wichita Falls]       United States
#
# [650 rows x 4 columns]

# %%
df = df.drop(columns=['Cities'])
df
# Out:
#                                              headlines           City  \
# 0                             Zika Outbreak Hits Miami          Miami
# 1                      Could Zika Reach New York City?  New York City
# 2                    First Case of Zika in Miami Beach    Miami Beach
# 3              Mystery Virus Spreads in Recife, Brazil         Recife
# 4              Dallas man comes down with case of Zika         Dallas
# ..                                                 ...            ...
# 645  Rumors about Rabies spreading in Jerusalem hav...      Jerusalem
# 646              More Zika patients reported in Indang         Indang
# 647  Suva authorities confirmed the spread of Rotav...           Suva
# 648         More Zika patients reported in Bella Vista    Bella Vista
# 649                     Zika Outbreak in Wichita Falls  Wichita Falls
#
#                 Country Country_Code
# 0         United States           US
# 1         United States           US
# 2         United States           US
# 3                Brazil           BR
# 4         United States           US
# ..                  ...          ...
# 645              Israel           IL
# 646         Philippines           PH
# 647                Fiji           FJ
# 648  Dominican Republic           DO
# 649       United States           US
#
# [650 rows x 4 columns]

# %%
df.describe()
# Out:
#                                    headlines City        Country Country_Code
# count                                    650  650            611          611
# unique                                   647  579             94           94
# top     Spanish Flu Spreading through Madrid       United States           US
# freq                                       2   39            302          302

# %%
df = df[df['City'] != '']
df
# Out:
#                                              headlines           City  \
# 0                             Zika Outbreak Hits Miami          Miami
# 1                      Could Zika Reach New York City?  New York City
# 2                    First Case of Zika in Miami Beach    Miami Beach
# 3              Mystery Virus Spreads in Recife, Brazil         Recife
# 4              Dallas man comes down with case of Zika         Dallas
# ..                                                 ...            ...
# 645  Rumors about Rabies spreading in Jerusalem hav...      Jerusalem
# 646              More Zika patients reported in Indang         Indang
# 647  Suva authorities confirmed the spread of Rotav...           Suva
# 648         More Zika patients reported in Bella Vista    Bella Vista
# 649                     Zika Outbreak in Wichita Falls  Wichita Falls
#
#                 Country Country_Code
# 0         United States           US
# 1         United States           US
# 2         United States           US
# 3                Brazil           BR
# 4         United States           US
# ..                  ...          ...
# 645              Israel           IL
# 646         Philippines           PH
# 647                Fiji           FJ
# 648  Dominican Republic           DO
# 649       United States           US
#
# [611 rows x 4 columns]

# %%
"""Build map and add features"""
import cartopy
from cartopy.crs import PlateCarree
import matplotlib.pyplot as plt 
plt.figure(figsize=(30,15))
ax = plt.axes(projection=PlateCarree())
def add_map_features():
    ax.coastlines()
    ax.add_feature(cartopy.feature.BORDERS)
    ax.add_feature(cartopy.feature.OCEAN)
    ax.add_feature(cartopy.feature.LAND)
    ax.add_feature(cartopy.feature.STATES)

add_map_features()
plt.show()
